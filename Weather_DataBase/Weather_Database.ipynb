# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90,size=2000)
lngs = np.random.uniform(-180,180,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
           cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities generated: {len(cities)}")
# Out:
# Number of cities generated: 729

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + API Key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description      
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_dscript = city_weather["weather"][0]["description"]
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_dscript})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | talnakh
# Processing Record 2 of Set 1 | burnie
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | east london
# Processing Record 6 of Set 1 | asau
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | noumea
# Processing Record 11 of Set 1 | airai
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | port-gentil
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | severo-yeniseyskiy
# Processing Record 16 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 1 | castro
# Processing Record 18 of Set 1 | kaitangata
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | basco
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | wajima
# Processing Record 23 of Set 1 | maykor
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 1 | bengkulu
# Processing Record 28 of Set 1 | longyearbyen
# Processing Record 29 of Set 1 | nanortalik
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | san pedro
# Processing Record 32 of Set 1 | sabzevar
# Processing Record 33 of Set 1 | weatherford
# Processing Record 34 of Set 1 | thompson
# Processing Record 35 of Set 1 | marawi
# Processing Record 36 of Set 1 | cherskiy
# Processing Record 37 of Set 1 | qaanaaq
# Processing Record 38 of Set 1 | berlevag
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | fatehpur
# Processing Record 41 of Set 1 | nisia floresta
# Processing Record 42 of Set 1 | siyabuswa
# Processing Record 43 of Set 1 | cap malheureux
# Processing Record 44 of Set 1 | saiha
# Processing Record 45 of Set 1 | lebu
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | chokurdakh
# Processing Record 49 of Set 1 | malm
# Processing Record 50 of Set 1 | arraial do cabo
# Processing Record 1 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 2 | tura
# Processing Record 3 of Set 2 | ribas do rio pardo
# Processing Record 4 of Set 2 | chuy
# Processing Record 5 of Set 2 | magadan
# Processing Record 6 of Set 2 | mataura
# Processing Record 7 of Set 2 | zhigansk
# Processing Record 8 of Set 2 | cayenne
# Processing Record 9 of Set 2 | coquimbo
# Processing Record 10 of Set 2 | kapaa
# Processing Record 11 of Set 2 | jalu
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | santiago de cuba
# Processing Record 14 of Set 2 | rikitea
# Processing Record 15 of Set 2 | cajati
# Processing Record 16 of Set 2 | odessa
# Processing Record 17 of Set 2 | ialibu
# Processing Record 18 of Set 2 | mineral wells
# Processing Record 19 of Set 2 | la ronge
# Processing Record 20 of Set 2 | meulaboh
# Processing Record 21 of Set 2 | tasiilaq
# Processing Record 22 of Set 2 | esso
# Processing Record 23 of Set 2 | mar del plata
# Processing Record 24 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 2 | sambava
# Processing Record 26 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 2 | camocim
# Processing Record 28 of Set 2 | ancud
# Processing Record 29 of Set 2 | zabol
# Processing Record 30 of Set 2 | pudozh
# Processing Record 31 of Set 2 | mahebourg
# Processing Record 32 of Set 2 | kochinda
# Processing Record 33 of Set 2 | mao
# Processing Record 34 of Set 2 | faya
# Processing Record 35 of Set 2 | rockford
# Processing Record 36 of Set 2 | klaksvik
# Processing Record 37 of Set 2 | varkaus
# Processing Record 38 of Set 2 | cairns
# Processing Record 39 of Set 2 | byron bay
# Processing Record 40 of Set 2 | henties bay
# Processing Record 41 of Set 2 | norman wells
# Processing Record 42 of Set 2 | wanning
# Processing Record 43 of Set 2 | camana
# Processing Record 44 of Set 2 | sorong
# Processing Record 45 of Set 2 | port alfred
# Processing Record 46 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 47 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 2 | trofors
# Processing Record 49 of Set 2 | new norfolk
# Processing Record 50 of Set 2 | emporia
# Processing Record 1 of Set 3 | mayumba
# Processing Record 2 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 3 | kathmandu
# Processing Record 4 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 3 | albany
# Processing Record 6 of Set 3 | gornopravdinsk
# Processing Record 7 of Set 3 | clyde river
# Processing Record 8 of Set 3 | piney green
# Processing Record 9 of Set 3 | paragominas
# Processing Record 10 of Set 3 | ust-nera
# Processing Record 11 of Set 3 | faanui
# Processing Record 12 of Set 3 | eydhafushi
# Processing Record 13 of Set 3 | saint-pierre
# Processing Record 14 of Set 3 | husavik
# Processing Record 15 of Set 3 | dikson
# Processing Record 16 of Set 3 | butterworth
# Processing Record 17 of Set 3 | maceio
# Processing Record 18 of Set 3 | rio gallegos
# Processing Record 19 of Set 3 | praia
# Processing Record 20 of Set 3 | dudinka
# Processing Record 21 of Set 3 | rantepao
# Processing Record 22 of Set 3 | orlik
# Processing Record 23 of Set 3 | atar
# Processing Record 24 of Set 3 | luderitz
# Processing Record 25 of Set 3 | jennings
# Processing Record 26 of Set 3 | jumla
# Processing Record 27 of Set 3 | viedma
# Processing Record 28 of Set 3 | hilo
# Processing Record 29 of Set 3 | dubai
# Processing Record 30 of Set 3 | fort nelson
# Processing Record 31 of Set 3 | namibe
# Processing Record 32 of Set 3 | isangel
# Processing Record 33 of Set 3 | port blair
# Processing Record 34 of Set 3 | stephenville
# Processing Record 35 of Set 3 | vila franca do campo
# Processing Record 36 of Set 3 | hobyo
# Processing Record 37 of Set 3 | haines junction
# Processing Record 38 of Set 3 | gold coast
# Processing Record 39 of Set 3 | bonthe
# Processing Record 40 of Set 3 | vardo
# Processing Record 41 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 3 | port hueneme
# Processing Record 43 of Set 3 | riyadh
# Processing Record 44 of Set 3 | port-cartier
# Processing Record 45 of Set 3 | ayan
# Processing Record 46 of Set 3 | lypova dolyna
# Processing Record 47 of Set 3 | dingle
# Processing Record 48 of Set 3 | esperance
# Processing Record 49 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 3 | caravelas
# Processing Record 1 of Set 4 | daru
# Processing Record 2 of Set 4 | auburn
# Processing Record 3 of Set 4 | roald
# Processing Record 4 of Set 4 | sur
# Processing Record 5 of Set 4 | kavieng
# Processing Record 6 of Set 4 | hobart
# Processing Record 7 of Set 4 | nemuro
# Processing Record 8 of Set 4 | carnarvon
# Processing Record 9 of Set 4 | souillac
# Processing Record 10 of Set 4 | pokhara
# Processing Record 11 of Set 4 | leningradskiy
# Processing Record 12 of Set 4 | san cristobal
# Processing Record 13 of Set 4 | figueiro
# Processing Record 14 of Set 4 | fukue
# Processing Record 15 of Set 4 | yessentukskaya
# Processing Record 16 of Set 4 | zhireken
# Processing Record 17 of Set 4 | rincon
# Processing Record 18 of Set 4 | severo-kurilsk
# Processing Record 19 of Set 4 | sao filipe
# Processing Record 20 of Set 4 | sitka
# Processing Record 21 of Set 4 | odweyne
# Processing Record 22 of Set 4 | bluff
# Processing Record 23 of Set 4 | tessalit
# Processing Record 24 of Set 4 | koumac
# Processing Record 25 of Set 4 | nouadhibou
# Processing Record 26 of Set 4 | skelleftea
# Processing Record 27 of Set 4 | preobrazheniye
# Processing Record 28 of Set 4 | herat
# Processing Record 29 of Set 4 | portland
# Processing Record 30 of Set 4 | chaa-khol
# City not found. Skipping...
# Processing Record 31 of Set 4 | mizdah
# Processing Record 32 of Set 4 | aguimes
# Processing Record 33 of Set 4 | new deer
# Processing Record 34 of Set 4 | hami
# Processing Record 35 of Set 4 | zhanaozen
# Processing Record 36 of Set 4 | saint-philippe
# Processing Record 37 of Set 4 | srednekolymsk
# Processing Record 38 of Set 4 | sabang
# Processing Record 39 of Set 4 | provideniya
# Processing Record 40 of Set 4 | karratha
# Processing Record 41 of Set 4 | mulanje
# Processing Record 42 of Set 4 | katsuura
# Processing Record 43 of Set 4 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 44 of Set 4 | coihaique
# Processing Record 45 of Set 4 | iqaluit
# Processing Record 46 of Set 4 | sokolo
# Processing Record 47 of Set 4 | vitim
# Processing Record 48 of Set 4 | cabo san lucas
# Processing Record 49 of Set 4 | rolim de moura
# City not found. Skipping...
# Processing Record 50 of Set 4 | kodiak
# Processing Record 1 of Set 5 | the valley
# Processing Record 2 of Set 5 | puntarenas
# Processing Record 3 of Set 5 | lazurne
# Processing Record 4 of Set 5 | togur
# Processing Record 5 of Set 5 | chambar
# Processing Record 6 of Set 5 | ketchikan
# Processing Record 7 of Set 5 | trat
# Processing Record 8 of Set 5 | marzuq
# Processing Record 9 of Set 5 | nikolskoye
# Processing Record 10 of Set 5 | baruun-urt
# Processing Record 11 of Set 5 | sibenik
# Processing Record 12 of Set 5 | lawrenceburg
# Processing Record 13 of Set 5 | garowe
# Processing Record 14 of Set 5 | waddan
# Processing Record 15 of Set 5 | catuday
# Processing Record 16 of Set 5 | xai-xai
# Processing Record 17 of Set 5 | adrar
# Processing Record 18 of Set 5 | codrington
# Processing Record 19 of Set 5 | salalah
# Processing Record 20 of Set 5 | raga
# Processing Record 21 of Set 5 | canning
# Processing Record 22 of Set 5 | mandera
# Processing Record 23 of Set 5 | ciras
# City not found. Skipping...
# Processing Record 24 of Set 5 | coahuayana
# Processing Record 25 of Set 5 | perigueux
# Processing Record 26 of Set 5 | banjar
# Processing Record 27 of Set 5 | gaya
# Processing Record 28 of Set 5 | kruisfontein
# Processing Record 29 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 5 | constitucion
# Processing Record 31 of Set 5 | grand-lahou
# Processing Record 32 of Set 5 | karwar
# Processing Record 33 of Set 5 | vestmannaeyjar
# Processing Record 34 of Set 5 | dillon
# Processing Record 35 of Set 5 | darhan
# Processing Record 36 of Set 5 | port lincoln
# Processing Record 37 of Set 5 | tiksi
# Processing Record 38 of Set 5 | ostrovnoy
# Processing Record 39 of Set 5 | bathsheba
# Processing Record 40 of Set 5 | sikeston
# Processing Record 41 of Set 5 | upernavik
# Processing Record 42 of Set 5 | pangody
# Processing Record 43 of Set 5 | nelson bay
# Processing Record 44 of Set 5 | saint george
# Processing Record 45 of Set 5 | namatanai
# Processing Record 46 of Set 5 | omboue
# Processing Record 47 of Set 5 | genhe
# Processing Record 48 of Set 5 | egvekinot
# Processing Record 49 of Set 5 | tir pol
# City not found. Skipping...
# Processing Record 50 of Set 5 | mega
# Processing Record 1 of Set 6 | vila velha
# Processing Record 2 of Set 6 | kopyevo
# City not found. Skipping...
# Processing Record 3 of Set 6 | asayita
# City not found. Skipping...
# Processing Record 4 of Set 6 | grottaferrata
# Processing Record 5 of Set 6 | alyangula
# Processing Record 6 of Set 6 | zhangye
# Processing Record 7 of Set 6 | sao joao da barra
# Processing Record 8 of Set 6 | porto novo
# Processing Record 9 of Set 6 | seoul
# Processing Record 10 of Set 6 | narsaq
# Processing Record 11 of Set 6 | beringovskiy
# Processing Record 12 of Set 6 | codo
# Processing Record 13 of Set 6 | larap
# Processing Record 14 of Set 6 | san quintin
# Processing Record 15 of Set 6 | adamus
# Processing Record 16 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 17 of Set 6 | saskylakh
# Processing Record 18 of Set 6 | victoria
# Processing Record 19 of Set 6 | kathu
# Processing Record 20 of Set 6 | la rioja
# Processing Record 21 of Set 6 | pevek
# Processing Record 22 of Set 6 | nizhniy ufaley
# Processing Record 23 of Set 6 | half moon bay
# Processing Record 24 of Set 6 | tuktoyaktuk
# Processing Record 25 of Set 6 | hargeysa
# Processing Record 26 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 27 of Set 6 | bagaces
# Processing Record 28 of Set 6 | mossendjo
# Processing Record 29 of Set 6 | bambous virieux
# Processing Record 30 of Set 6 | boa vista
# Processing Record 31 of Set 6 | surab
# Processing Record 32 of Set 6 | meadow lake
# Processing Record 33 of Set 6 | strezhevoy
# Processing Record 34 of Set 6 | yarada
# Processing Record 35 of Set 6 | avera
# Processing Record 36 of Set 6 | visby
# Processing Record 37 of Set 6 | buraydah
# Processing Record 38 of Set 6 | havelock
# Processing Record 39 of Set 6 | mount isa
# Processing Record 40 of Set 6 | gushikawa
# Processing Record 41 of Set 6 | acapulco
# Processing Record 42 of Set 6 | kununurra
# Processing Record 43 of Set 6 | bethel
# Processing Record 44 of Set 6 | hay river
# Processing Record 45 of Set 6 | paucartambo
# City not found. Skipping...
# Processing Record 46 of Set 6 | tevaitoa
# Processing Record 47 of Set 6 | gore
# Processing Record 48 of Set 6 | ziarat
# Processing Record 49 of Set 6 | itapolis
# Processing Record 50 of Set 6 | tautira
# Processing Record 1 of Set 7 | copiapo
# Processing Record 2 of Set 7 | sorland
# Processing Record 3 of Set 7 | piacabucu
# Processing Record 4 of Set 7 | timiryazevskiy
# Processing Record 5 of Set 7 | marienburg
# Processing Record 6 of Set 7 | kolo
# Processing Record 7 of Set 7 | makhachkala
# Processing Record 8 of Set 7 | gamba
# Processing Record 9 of Set 7 | saldanha
# Processing Record 10 of Set 7 | kaniama
# Processing Record 11 of Set 7 | chernyshevskiy
# Processing Record 12 of Set 7 | rabo de peixe
# Processing Record 13 of Set 7 | torbay
# Processing Record 14 of Set 7 | braunau
# Processing Record 15 of Set 7 | tete
# Processing Record 16 of Set 7 | lazaro cardenas
# Processing Record 17 of Set 7 | omaruru
# Processing Record 18 of Set 7 | manggar
# Processing Record 19 of Set 7 | umm lajj
# Processing Record 20 of Set 7 | aklavik
# Processing Record 21 of Set 7 | esna
# Processing Record 22 of Set 7 | muscat
# Processing Record 23 of Set 7 | iznoski
# Processing Record 24 of Set 7 | el tigre
# Processing Record 25 of Set 7 | amuntai
# Processing Record 26 of Set 7 | ithaca
# Processing Record 27 of Set 7 | vesele
# Processing Record 28 of Set 7 | emerald
# Processing Record 29 of Set 7 | hasaki
# Processing Record 30 of Set 7 | biak
# Processing Record 31 of Set 7 | oranjemund
# Processing Record 32 of Set 7 | imatra
# Processing Record 33 of Set 7 | songea
# Processing Record 34 of Set 7 | ereymentau
# Processing Record 35 of Set 7 | zhuhai
# Processing Record 36 of Set 7 | san carlos de bariloche
# Processing Record 37 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 7 | chara
# Processing Record 39 of Set 7 | ilulissat
# Processing Record 40 of Set 7 | karambakkudi
# Processing Record 41 of Set 7 | kalaleh
# Processing Record 42 of Set 7 | okha
# Processing Record 43 of Set 7 | praia da vitoria
# Processing Record 44 of Set 7 | fortuna
# Processing Record 45 of Set 7 | havre-saint-pierre
# Processing Record 46 of Set 7 | rawson
# Processing Record 47 of Set 7 | sinnamary
# Processing Record 48 of Set 7 | filadelfia
# Processing Record 49 of Set 7 | volot
# Processing Record 50 of Set 7 | wamba
# Processing Record 1 of Set 8 | lucea
# Processing Record 2 of Set 8 | cidreira
# Processing Record 3 of Set 8 | maniitsoq
# Processing Record 4 of Set 8 | gazni
# City not found. Skipping...
# Processing Record 5 of Set 8 | nizhniy tsasuchey
# Processing Record 6 of Set 8 | russell
# Processing Record 7 of Set 8 | boca do acre
# Processing Record 8 of Set 8 | kiunga
# Processing Record 9 of Set 8 | port elizabeth
# Processing Record 10 of Set 8 | guzelyurt
# Processing Record 11 of Set 8 | georgetown
# Processing Record 12 of Set 8 | geraldton
# Processing Record 13 of Set 8 | ahipara
# Processing Record 14 of Set 8 | poum
# Processing Record 15 of Set 8 | leh
# Processing Record 16 of Set 8 | honningsvag
# Processing Record 17 of Set 8 | san andres
# Processing Record 18 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 19 of Set 8 | iracoubo
# Processing Record 20 of Set 8 | vanavara
# Processing Record 21 of Set 8 | emmett
# Processing Record 22 of Set 8 | krasnyy oktyabr
# Processing Record 23 of Set 8 | sovetskaya gavan
# Processing Record 24 of Set 8 | kharp
# Processing Record 25 of Set 8 | boden
# Processing Record 26 of Set 8 | laon
# Processing Record 27 of Set 8 | kahului
# Processing Record 28 of Set 8 | aksarka
# Processing Record 29 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 30 of Set 8 | mount pleasant
# Processing Record 31 of Set 8 | neuquen
# Processing Record 32 of Set 8 | xiaoweizhai
# Processing Record 33 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 34 of Set 8 | fethiye
# Processing Record 35 of Set 8 | mahajanga
# Processing Record 36 of Set 8 | kholmogory
# Processing Record 37 of Set 8 | vao
# Processing Record 38 of Set 8 | pangnirtung
# Processing Record 39 of Set 8 | touros
# Processing Record 40 of Set 8 | kloulklubed
# Processing Record 41 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 8 | necochea
# Processing Record 43 of Set 8 | sechura
# Processing Record 44 of Set 8 | bida
# Processing Record 45 of Set 8 | kitob
# Processing Record 46 of Set 8 | flinders
# Processing Record 47 of Set 8 | slonim
# Processing Record 48 of Set 8 | santa cruz
# Processing Record 49 of Set 8 | tiarei
# Processing Record 50 of Set 8 | balatonfured
# Processing Record 1 of Set 9 | basqal
# Processing Record 2 of Set 9 | pitimbu
# Processing Record 3 of Set 9 | los llanos de aridane
# Processing Record 4 of Set 9 | borkenes
# Processing Record 5 of Set 9 | loandjili
# Processing Record 6 of Set 9 | oussouye
# Processing Record 7 of Set 9 | sao miguel do araguaia
# Processing Record 8 of Set 9 | saint-francois
# Processing Record 9 of Set 9 | te anau
# Processing Record 10 of Set 9 | kuytun
# Processing Record 11 of Set 9 | lompoc
# Processing Record 12 of Set 9 | diego de almagro
# Processing Record 13 of Set 9 | saryg-sep
# Processing Record 14 of Set 9 | lagoa
# Processing Record 15 of Set 9 | brownsville
# Processing Record 16 of Set 9 | samarai
# Processing Record 17 of Set 9 | lorengau
# Processing Record 18 of Set 9 | takoradi
# Processing Record 19 of Set 9 | cururupu
# Processing Record 20 of Set 9 | chaah
# Processing Record 21 of Set 9 | evensk
# Processing Record 22 of Set 9 | cochrane
# Processing Record 23 of Set 9 | sola
# Processing Record 24 of Set 9 | okhotsk
# Processing Record 25 of Set 9 | ozernovskiy
# Processing Record 26 of Set 9 | muroto
# Processing Record 27 of Set 9 | manaus
# Processing Record 28 of Set 9 | hithadhoo
# Processing Record 29 of Set 9 | khatanga
# Processing Record 30 of Set 9 | buala
# Processing Record 31 of Set 9 | krasnoselkup
# Processing Record 32 of Set 9 | jamame
# Processing Record 33 of Set 9 | anakapalle
# Processing Record 34 of Set 9 | peniche
# Processing Record 35 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 36 of Set 9 | college
# Processing Record 37 of Set 9 | nevelsk
# Processing Record 38 of Set 9 | waipawa
# Processing Record 39 of Set 9 | dali
# Processing Record 40 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 9 | cascais
# Processing Record 42 of Set 9 | sampit
# Processing Record 43 of Set 9 | llangefni
# Processing Record 44 of Set 9 | mastung
# Processing Record 45 of Set 9 | barra do garcas
# Processing Record 46 of Set 9 | kondinskoye
# Processing Record 47 of Set 9 | buin
# Processing Record 48 of Set 9 | fortuna foothills
# Processing Record 49 of Set 9 | pisco
# Processing Record 50 of Set 9 | paraiso
# Processing Record 1 of Set 10 | manado
# Processing Record 2 of Set 10 | kawana waters
# City not found. Skipping...
# Processing Record 3 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 5 of Set 10 | naze
# Processing Record 6 of Set 10 | bloemhof
# Processing Record 7 of Set 10 | qeshm
# Processing Record 8 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 9 of Set 10 | erenhot
# Processing Record 10 of Set 10 | hamilton
# Processing Record 11 of Set 10 | hailar
# Processing Record 12 of Set 10 | verkhnevilyuysk
# Processing Record 13 of Set 10 | troitskoye
# Processing Record 14 of Set 10 | dwarka
# Processing Record 15 of Set 10 | chalmette
# Processing Record 16 of Set 10 | andarab
# City not found. Skipping...
# Processing Record 17 of Set 10 | alta floresta
# Processing Record 18 of Set 10 | ucluelet
# Processing Record 19 of Set 10 | north bend
# Processing Record 20 of Set 10 | san patricio
# Processing Record 21 of Set 10 | bilibino
# Processing Record 22 of Set 10 | burgersdorp
# Processing Record 23 of Set 10 | akyab
# Processing Record 24 of Set 10 | kalamb
# Processing Record 25 of Set 10 | cockburn town
# Processing Record 26 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 10 | cabedelo
# Processing Record 28 of Set 10 | masunga
# Processing Record 29 of Set 10 | san ramon
# Processing Record 30 of Set 10 | kyshtovka
# Processing Record 31 of Set 10 | antofagasta
# Processing Record 32 of Set 10 | somerset east
# Processing Record 33 of Set 10 | tarko-sale
# Processing Record 34 of Set 10 | camacha
# Processing Record 35 of Set 10 | sasina
# Processing Record 36 of Set 10 | margate
# Processing Record 37 of Set 10 | nizhniy kuranakh
# Processing Record 38 of Set 10 | lakatoro
# Processing Record 39 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 10 | dunedin
# Processing Record 41 of Set 10 | santa catalina
# Processing Record 42 of Set 10 | zalantun
# Processing Record 43 of Set 10 | nileshwar
# Processing Record 44 of Set 10 | ghanzi
# Processing Record 45 of Set 10 | tupa
# Processing Record 46 of Set 10 | tual
# Processing Record 47 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 48 of Set 10 | bayonet point
# Processing Record 49 of Set 10 | solnechnyy
# Processing Record 50 of Set 10 | kishtwar
# Processing Record 1 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 11 | ocampo
# Processing Record 3 of Set 11 | svetlyy
# Processing Record 4 of Set 11 | blackwater
# Processing Record 5 of Set 11 | sao felix do xingu
# Processing Record 6 of Set 11 | tuatapere
# Processing Record 7 of Set 11 | pereslavl-zalesskiy
# Processing Record 8 of Set 11 | pandan
# Processing Record 9 of Set 11 | dourbali
# Processing Record 10 of Set 11 | burgeo
# Processing Record 11 of Set 11 | saint anthony
# Processing Record 12 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 13 of Set 11 | alofi
# Processing Record 14 of Set 11 | abu dhabi
# Processing Record 15 of Set 11 | marsabit
# Processing Record 16 of Set 11 | pucallpa
# Processing Record 17 of Set 11 | pemangkat
# Processing Record 18 of Set 11 | puerto colombia
# Processing Record 19 of Set 11 | kirakira
# Processing Record 20 of Set 11 | comodoro rivadavia
# Processing Record 21 of Set 11 | itarema
# Processing Record 22 of Set 11 | vrangel
# Processing Record 23 of Set 11 | kieta
# Processing Record 24 of Set 11 | tres picos
# Processing Record 25 of Set 11 | fairhaven
# Processing Record 26 of Set 11 | mbandaka
# Processing Record 27 of Set 11 | mahibadhoo
# Processing Record 28 of Set 11 | hovd
# Processing Record 29 of Set 11 | manuk mangkaw
# Processing Record 30 of Set 11 | lang suan
# Processing Record 31 of Set 11 | winsford
# Processing Record 32 of Set 11 | sosnytsya
# Processing Record 33 of Set 11 | guerrero negro
# Processing Record 34 of Set 11 | guadalupe y calvo
# Processing Record 35 of Set 11 | ponta do sol
# Processing Record 36 of Set 11 | mindelo
# Processing Record 37 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 38 of Set 11 | mackenzie
# Processing Record 39 of Set 11 | taltal
# Processing Record 40 of Set 11 | udachnyy
# Processing Record 41 of Set 11 | vostok
# Processing Record 42 of Set 11 | barra patuca
# Processing Record 43 of Set 11 | plauen
# Processing Record 44 of Set 11 | elizabeth city
# Processing Record 45 of Set 11 | kavaratti
# Processing Record 46 of Set 11 | bhopal
# Processing Record 47 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 48 of Set 11 | jackson
# Processing Record 49 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 11 | rock sound
# Processing Record 1 of Set 12 | anadyr
# Processing Record 2 of Set 12 | palampur
# Processing Record 3 of Set 12 | ouadda
# Processing Record 4 of Set 12 | uvira
# Processing Record 5 of Set 12 | trairi
# Processing Record 6 of Set 12 | barmer
# Processing Record 7 of Set 12 | candolim
# Processing Record 8 of Set 12 | ulaanbaatar
# Processing Record 9 of Set 12 | christchurch
# Processing Record 10 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 12 | deputatskiy
# Processing Record 12 of Set 12 | ixtapa
# Processing Record 13 of Set 12 | east foothills
# Processing Record 14 of Set 12 | portobelo
# Processing Record 15 of Set 12 | xining
# Processing Record 16 of Set 12 | sovetskiy
# Processing Record 17 of Set 12 | dicabisagan
# Processing Record 18 of Set 12 | pemba
# Processing Record 19 of Set 12 | beruni
# City not found. Skipping...
# Processing Record 20 of Set 12 | eureka
# Processing Record 21 of Set 12 | muros
# Processing Record 22 of Set 12 | shache
# Processing Record 23 of Set 12 | matagami
# Processing Record 24 of Set 12 | glubokoe
# City not found. Skipping...
# Processing Record 25 of Set 12 | khani
# Processing Record 26 of Set 12 | coremas
# Processing Record 27 of Set 12 | acajutla
# Processing Record 28 of Set 12 | zhezkazgan
# Processing Record 29 of Set 12 | araouane
# Processing Record 30 of Set 12 | maldonado
# Processing Record 31 of Set 12 | rodrigues alves
# Processing Record 32 of Set 12 | haimen
# Processing Record 33 of Set 12 | terney
# Processing Record 34 of Set 12 | domoni
# Processing Record 35 of Set 12 | kaka
# Processing Record 36 of Set 12 | warwick
# Processing Record 37 of Set 12 | kuito
# Processing Record 38 of Set 12 | baykit
# Processing Record 39 of Set 12 | port hardy
# Processing Record 40 of Set 12 | bilma
# Processing Record 41 of Set 12 | negrar
# Processing Record 42 of Set 12 | constantine
# Processing Record 43 of Set 12 | vryburg
# Processing Record 44 of Set 12 | huicheng
# Processing Record 45 of Set 12 | boende
# Processing Record 46 of Set 12 | olafsvik
# Processing Record 47 of Set 12 | omsukchan
# Processing Record 48 of Set 12 | panaba
# Processing Record 49 of Set 12 | luau
# Processing Record 50 of Set 12 | moen
# Processing Record 1 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 13 | santa rosa
# Processing Record 3 of Set 13 | kon tum
# Processing Record 4 of Set 13 | chany
# Processing Record 5 of Set 13 | sinazongwe
# Processing Record 6 of Set 13 | guarapari
# Processing Record 7 of Set 13 | changji
# Processing Record 8 of Set 13 | boquete
# Processing Record 9 of Set 13 | sakaiminato
# Processing Record 10 of Set 13 | aswan
# Processing Record 11 of Set 13 | santiago del estero
# Processing Record 12 of Set 13 | nikko
# Processing Record 13 of Set 13 | zaoyang
# Processing Record 14 of Set 13 | hokitika
# Processing Record 15 of Set 13 | mawlaik
# Processing Record 16 of Set 13 | milledgeville
# Processing Record 17 of Set 13 | calvinia
# Processing Record 18 of Set 13 | kaeo
# Processing Record 19 of Set 13 | viransehir
# Processing Record 20 of Set 13 | pietersburg
# Processing Record 21 of Set 13 | fayaoue
# Processing Record 22 of Set 13 | pucara
# Processing Record 23 of Set 13 | okato
# Processing Record 24 of Set 13 | bato
# Processing Record 25 of Set 13 | biharamulo
# Processing Record 26 of Set 13 | otane
# Processing Record 27 of Set 13 | wilmington island
# Processing Record 28 of Set 13 | yuzhne
# Processing Record 29 of Set 13 | port moresby
# Processing Record 30 of Set 13 | nuuk
# Processing Record 31 of Set 13 | ola
# Processing Record 32 of Set 13 | partsa
# Processing Record 33 of Set 13 | merrill
# Processing Record 34 of Set 13 | antalaha
# Processing Record 35 of Set 13 | wawa
# Processing Record 36 of Set 13 | manzil salim
# Processing Record 37 of Set 13 | dalvik
# Processing Record 38 of Set 13 | pacifica
# Processing Record 39 of Set 13 | bantayan
# Processing Record 40 of Set 13 | fairbanks
# Processing Record 41 of Set 13 | iquitos
# Processing Record 42 of Set 13 | talcahuano
# Processing Record 43 of Set 13 | yulara
# Processing Record 44 of Set 13 | zhoucheng
# Processing Record 45 of Set 13 | bay-khaak
# Processing Record 46 of Set 13 | luanda
# Processing Record 47 of Set 13 | zhongshu
# Processing Record 48 of Set 13 | pokrovsk
# Processing Record 49 of Set 13 | oksfjord
# Processing Record 50 of Set 13 | show low
# Processing Record 1 of Set 14 | waingapu
# Processing Record 2 of Set 14 | salisbury
# Processing Record 3 of Set 14 | kattivakkam
# Processing Record 4 of Set 14 | vernon
# Processing Record 5 of Set 14 | mareeba
# Processing Record 6 of Set 14 | yaan
# Processing Record 7 of Set 14 | tabou
# Processing Record 8 of Set 14 | sept-iles
# Processing Record 9 of Set 14 | topola
# Processing Record 10 of Set 14 | polovinnoye
# Processing Record 11 of Set 14 | la paz
# Processing Record 12 of Set 14 | bumbuna
# Processing Record 13 of Set 14 | tigil
# Processing Record 14 of Set 14 | abalak
# Processing Record 15 of Set 14 | bukene
# Processing Record 16 of Set 14 | belyy yar
# Processing Record 17 of Set 14 | mount gambier
# Processing Record 18 of Set 14 | erdenet
# Processing Record 19 of Set 14 | valparaiso
# Processing Record 20 of Set 14 | ambon
# Processing Record 21 of Set 14 | bandarbeyla
# Processing Record 22 of Set 14 | le mars
# Processing Record 23 of Set 14 | nador
# Processing Record 24 of Set 14 | malakal
# Processing Record 25 of Set 14 | puerto escondido
# Processing Record 26 of Set 14 | nabire
# Processing Record 27 of Set 14 | adamas
# Processing Record 28 of Set 14 | cukai
# Processing Record 29 of Set 14 | lerwick
# Processing Record 30 of Set 14 | jiutai
# Processing Record 31 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 14 | pedernales
# Processing Record 33 of Set 14 | tadine
# Processing Record 34 of Set 14 | sarramea
# Processing Record 35 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 36 of Set 14 | umba
# Processing Record 37 of Set 14 | beian
# Processing Record 38 of Set 14 | padang
# Processing Record 39 of Set 14 | chapais
# Processing Record 40 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 41 of Set 14 | mecca
# Processing Record 42 of Set 14 | burhanpur
# Processing Record 43 of Set 14 | tha chang
# Processing Record 44 of Set 14 | gomel
# Processing Record 45 of Set 14 | omemee
# Processing Record 46 of Set 14 | palmer
# Processing Record 47 of Set 14 | marsa matruh
# Processing Record 48 of Set 14 | lensk
# Processing Record 49 of Set 14 | lavrentiya
# Processing Record 50 of Set 14 | broome
# Processing Record 1 of Set 15 | ville-marie
# Processing Record 2 of Set 15 | semey
# Processing Record 3 of Set 15 | komsomolskiy
# Processing Record 4 of Set 15 | aykhal
# Processing Record 5 of Set 15 | sigli
# Processing Record 6 of Set 15 | soltepec
# Processing Record 7 of Set 15 | opuwo
# Processing Record 8 of Set 15 | tenosique
# Processing Record 9 of Set 15 | nome
# Processing Record 10 of Set 15 | boyuibe
# Processing Record 11 of Set 15 | penticton
# Processing Record 12 of Set 15 | santa fe
# Processing Record 13 of Set 15 | camacupa
# Processing Record 14 of Set 15 | manakara
# Processing Record 15 of Set 15 | pringsewu
# Processing Record 16 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 15 | batagay-alyta
# Processing Record 18 of Set 15 | sorsk
# Processing Record 19 of Set 15 | khash
# Processing Record 20 of Set 15 | el alto
# Processing Record 21 of Set 15 | san diego de los banos
# Processing Record 22 of Set 15 | asfi
# Processing Record 23 of Set 15 | tshikapa
# Processing Record 24 of Set 15 | mineros
# Processing Record 25 of Set 15 | hibbing
# Processing Record 26 of Set 15 | sawakin
# Processing Record 27 of Set 15 | hanyang
# Processing Record 28 of Set 15 | makubetsu
# Processing Record 29 of Set 15 | mandurah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 677

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Talnakh      RU  69.4865   88.3972     -1.71        99         100
# 1        Burnie      AU -41.0667  145.9167     55.98        74           6
# 2        Atuona      PF  -9.8000 -139.0333     77.67        80          28
# 3    Butaritari      KI   3.0707  172.7902     81.05        79          62
# 4   East London      ZA -33.0153   27.9116     72.54        83          40
# 5          Asau      RO  46.4333   26.4000     29.32        75         100
# 6     Jamestown      US  42.0970  -79.2353     31.59        95         100
# 7       Ushuaia      AR -54.8000  -68.3000     47.86        61          40
# 8  Puerto Ayora      EC  -0.7393  -90.3518     66.54        95          87
# 9        Noumea      NC -22.2763  166.4572     84.00        99          65
#
#    Wind Speed Current Description
# 0        0.76     overcast clouds
# 1        9.73           clear sky
# 2       14.47    scattered clouds
# 3       12.86       broken clouds
# 4        6.91    scattered clouds
# 5        3.67     overcast clouds
# 6       14.97                mist
# 7        5.75    scattered clouds
# 8       10.71     overcast clouds
# 9        3.74          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
cities_data_df = city_data_df[['City', 'Country', 'Lat', 'Lng','Max Temp','Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']]

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
cities_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Talnakh      RU  69.4865   88.3972     -1.71        99         100
# 1       Burnie      AU -41.0667  145.9167     55.98        74           6
# 2       Atuona      PF  -9.8000 -139.0333     77.67        80          28
# 3   Butaritari      KI   3.0707  172.7902     81.05        79          62
# 4  East London      ZA -33.0153   27.9116     72.54        83          40
#
#    Wind Speed Current Description
# 0        0.76     overcast clouds
# 1        9.73           clear sky
# 2       14.47    scattered clouds
# 3       12.86       broken clouds
# 4        6.91    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
cities_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
cities_data_df.to_csv(output_data_file, index_label="City_ID")
