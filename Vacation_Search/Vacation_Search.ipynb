# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("Weather_Database/WeatherPy_database.csv")
city_data_df.head()

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0      Talnakh      RU  69.4865   88.3972     -1.71        99
# 1        1       Burnie      AU -41.0667  145.9167     55.98        74
# 2        2       Atuona      PF  -9.8000 -139.0333     77.67        80
# 3        3   Butaritari      KI   3.0707  172.7902     81.05        79
# 4        4  East London      ZA -33.0153   27.9116     72.54        83
#
#    Cloudiness  Wind Speed Current Description
# 0         100        0.76     overcast clouds
# 1           6        9.73           clear sky
# 2          28       14.47    scattered clouds
# 3          62       12.86       broken clouds
# 4          40        6.91    scattered clouds

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? -80
# What is the maximum temperature you would like for your trip? 100

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]

# Display sample data
preferred_cities_df.head()
# Out:
#    City_ID         City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0      Talnakh      RU  69.4865   88.3972     -1.71        99
# 1        1       Burnie      AU -41.0667  145.9167     55.98        74
# 2        2       Atuona      PF  -9.8000 -139.0333     77.67        80
# 3        3   Butaritari      KI   3.0707  172.7902     81.05        79
# 4        4  East London      ZA -33.0153   27.9116     72.54        83
#
#    Cloudiness  Wind Speed Current Description
# 0         100        0.76     overcast clouds
# 1           6        9.73           clear sky
# 2          28       14.47    scattered clouds
# 3          62       12.86       broken clouds
# 4          40        6.91    scattered clouds

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty row
preferred_cities_df = preferred_cities_df.dropna()

# Display sample data
preferred_cities_df.head()
# Out:
#    City_ID         City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0      Talnakh      RU  69.4865   88.3972     -1.71        99
# 1        1       Burnie      AU -41.0667  145.9167     55.98        74
# 2        2       Atuona      PF  -9.8000 -139.0333     77.67        80
# 3        3   Butaritari      KI   3.0707  172.7902     81.05        79
# 4        4  East London      ZA -33.0153   27.9116     72.54        83
#
#    Cloudiness  Wind Speed Current Description
# 0         100        0.76     overcast clouds
# 1           6        9.73           clear sky
# 2          28       14.47    scattered clouds
# 3          62       12.86       broken clouds
# 4          40        6.91    scattered clouds

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".
hotel_df["Hotel Name"] = None


# Display sample data
hotel_df.head(10)
# Out:
#            City Country  Max Temp Current Description      Lat       Lng  \
# 0       Talnakh      RU     -1.71     overcast clouds  69.4865   88.3972
# 1        Burnie      AU     55.98           clear sky -41.0667  145.9167
# 2        Atuona      PF     77.67    scattered clouds  -9.8000 -139.0333
# 3    Butaritari      KI     81.05       broken clouds   3.0707  172.7902
# 4   East London      ZA     72.54    scattered clouds -33.0153   27.9116
# 5          Asau      RO     29.32     overcast clouds  46.4333   26.4000
# 6     Jamestown      US     31.59                mist  42.0970  -79.2353
# 7       Ushuaia      AR     47.86    scattered clouds -54.8000  -68.3000
# 8  Puerto Ayora      EC     66.54     overcast clouds  -0.7393  -90.3518
# 9        Noumea      NC     84.00          light rain -22.2763  166.4572
#
#   Hotel Name
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5       None
# 6       None
# 7       None
# 8       None
# 9       None

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Iterate through the hotel DataFrame

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Get the first hotel from the results and store the name, if a hotel isn't found set the hotel name as "No hotel found".
    try:
       hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Talnakh - nearest hotel: Талнах
# Burnie - nearest hotel: Burnie Central TownHouse Hotel
# Atuona - nearest hotel: Pearl Resort
# Butaritari - nearest hotel: No hotel found
# East London - nearest hotel: No hotel found
# Asau - nearest hotel: No hotel found
# Jamestown - nearest hotel: DoubleTree Jamestown
# Ushuaia - nearest hotel: Apart Hotel Aires del Beagle
# Puerto Ayora - nearest hotel: Hostal La Mirada De Solitario George
# Noumea - nearest hotel: Hotel Gondwana
# Airai - nearest hotel: No hotel found
# Avarua - nearest hotel: Paradise Inn
# Port-Gentil - nearest hotel: Tara-Mé
# Punta Arenas - nearest hotel: Hotel Lacolet
# Severo-Yeniseyskiy - nearest hotel: Актолик
# Castro - nearest hotel: Hotel Central Palace
# Kaitangata - nearest hotel: No hotel found
# Barrow - nearest hotel: No hotel found
# Basco - nearest hotel: Tawsen Hotel
# Hermanus - nearest hotel: Aloe guest house
# Wajima - nearest hotel: 八汐
# Maykor - nearest hotel: No hotel found
# Yellowknife - nearest hotel: No hotel found
# Ribeira Grande - nearest hotel: No hotel found
# Bengkulu - nearest hotel: Dena Hotel
# Longyearbyen - nearest hotel: The Vault
# Nanortalik - nearest hotel: Kap Farvel
# Vaini - nearest hotel: Keleti International Resort
# San Pedro - nearest hotel: Hotel Takara
# Sabzevar - nearest hotel: مامورسرا مخابرات سبزوار
# Weatherford - nearest hotel: Clarion
# Thompson - nearest hotel: Thompson Inn
# Marawi - nearest hotel: Marawi Resort Hotel
# Cherskiy - nearest hotel: No hotel found
# Qaanaaq - nearest hotel: Hotel Qaanaaq
# Berlevag - nearest hotel: No hotel found
# Fatehpur - nearest hotel: No hotel found
# Nisia Floresta - nearest hotel: No hotel found
# Siyabuswa - nearest hotel: No hotel found
# Cap Malheureux - nearest hotel: Cape Garden
# Saiha - nearest hotel: No hotel found
# Lebu - nearest hotel: No hotel found
# Busselton - nearest hotel: No hotel found
# Cape Town - nearest hotel: Townhouse Hotel
# Chokurdakh - nearest hotel: No hotel found
# Malm - nearest hotel: No hotel found
# Arraial Do Cabo - nearest hotel: No hotel found
# Tura - nearest hotel: No hotel found
# Ribas Do Rio Pardo - nearest hotel: Hotel São Francisco
# Chuy - nearest hotel: Alerces
# Magadan - nearest hotel: Гостиница «ВМ-Центр»
# Mataura - nearest hotel: No hotel found
# Zhigansk - nearest hotel: ИП Пав
# Cayenne - nearest hotel: Central Hôtel
# Coquimbo - nearest hotel: Hotel Iberia
# Kapaa - nearest hotel: Pono Kai Resort
# Jalu - nearest hotel: فندق جالو السياحي
# Bredasdorp - nearest hotel: Victoria Hotel
# Santiago De Cuba - nearest hotel: Rex
# Rikitea - nearest hotel: Chez Bianca & Benoit
# Cajati - nearest hotel: Sueber
# Odessa - nearest hotel: Venus Hotel
# Ialibu - nearest hotel: No hotel found
# Mineral Wells - nearest hotel: Baker Hotel
# La Ronge - nearest hotel: La Ronge Hotel and Suites
# Meulaboh - nearest hotel: Hotel Meuligou
# Tasiilaq - nearest hotel: Angmagssalik
# Esso - nearest hotel: Горизонты Камчатки
# Mar Del Plata - nearest hotel: Nuevo Ostende
# Sambava - nearest hotel: Royal Sava Hôtel
# Camocim - nearest hotel: Hotel Dunas
# Ancud - nearest hotel: Cabañas
# Zabol - nearest hotel: No hotel found
# Pudozh - nearest hotel: Карел-Онего
# Mahebourg - nearest hotel: Grand Bel Air
# Kochinda - nearest hotel: No hotel found
# Mao - nearest hotel: Eurohotel
# Faya - nearest hotel: No hotel found
# Rockford - nearest hotel: Lafayette Hotel
# Klaksvik - nearest hotel: Hotel Klaksvik
# Varkaus - nearest hotel: Hotel Oscar
# Cairns - nearest hotel: Cairns Queens Court Accommodation
# Byron Bay - nearest hotel: Lord Byron Resort
# Norman Wells - nearest hotel: Yamouri Inn
# Wanning - nearest hotel: No hotel found
# Camana - nearest hotel: Caja Arequipa
# Sorong - nearest hotel: Hotel Membramo Marina
# Port Alfred - nearest hotel: No hotel found
# Trofors - nearest hotel: No hotel found
# New Norfolk - nearest hotel: Woodbridge on the Derwent
# Emporia - nearest hotel: Budget Host Inn Emporia
# Mayumba - nearest hotel: Résidence Hôtelière Fabso
# Kathmandu - nearest hotel: Aryatara Kathmandu Hotel
# Albany - nearest hotel: No hotel found
# Gornopravdinsk - nearest hotel: Гостинный двор
# Clyde River - nearest hotel: No hotel found
# Piney Green - nearest hotel: No hotel found
# Paragominas - nearest hotel: No hotel found
# Ust-Nera - nearest hotel: гостиница "Солнечная"
# Faanui - nearest hotel: Oa Oa Lodge
# Eydhafushi - nearest hotel: No hotel found
# Saint-Pierre - nearest hotel: Tropic Hotel
# Husavik - nearest hotel: Fosshótel Húsavík
# Dikson - nearest hotel: No hotel found
# Butterworth - nearest hotel: No hotel found
# Maceio - nearest hotel: Maceió Hostel e Pousada
# Rio Gallegos - nearest hotel: Amérian Río Gallegos Apart & Suites
# Praia - nearest hotel: Casa Sodadi
# Dudinka - nearest hotel: Виктория
# Rantepao - nearest hotel: Hotel Indra Toraja
# Orlik - nearest hotel: Ая ганга
# Atar - nearest hotel: فندق سكليل
# Jennings - nearest hotel: Carousel Motel
# Jumla - nearest hotel: Amar Sandesh Guesthouse
# Viedma - nearest hotel: Níjar
# Hilo - nearest hotel: Dolphin Bay Hotel
# Dubai - nearest hotel: Holiday Inn Bur Dubai - Embassy District
# Fort Nelson - nearest hotel: Fort Nelson Hotel
# Ocampo - nearest hotel: No hotel found
# Svetlyy - nearest hotel: No hotel found
# Blackwater - nearest hotel: No hotel found
# Sao Felix Do Xingu - nearest hotel: Hotel Terraço
# Tuatapere - nearest hotel: No hotel found
# Pereslavl-Zalesskiy - nearest hotel: Западная
# Pandan - nearest hotel: No hotel found
# Dourbali - nearest hotel: No hotel found
# Burgeo - nearest hotel: No hotel found
# Saint Anthony - nearest hotel: Delta Hotels by Marriott
# Alofi - nearest hotel: No hotel found
# Abu Dhabi - nearest hotel: Marriott Downtown Abu-Dhabi
# Marsabit - nearest hotel: Chicho Hotel
# Pucallpa - nearest hotel: Hospedaje Cristofer
# Pemangkat - nearest hotel: Hotel Kelapa Gading
# Puerto Colombia - nearest hotel: Hotel Puerto Colombia
# Kirakira - nearest hotel: No hotel found
# Comodoro Rivadavia - nearest hotel: No hotel found
# Itarema - nearest hotel: Pousada Oásis
# Vrangel - nearest hotel: No hotel found
# Kieta - nearest hotel: No hotel found
# Tres Picos - nearest hotel: Hotel Tres Picos
# Fairhaven - nearest hotel: Fairfield Inn and Suites by Marriott New Bedford
# Mbandaka - nearest hotel: Hôtel Epervier
# Mahibadhoo - nearest hotel: Coral View Inn
# Hovd - nearest hotel: Khovd hotel
# Manuk Mangkaw - nearest hotel: No hotel found
# Lang Suan - nearest hotel: โรงแรมธวัช
# Winsford - nearest hotel: The Winsford Lodge
# Sosnytsya - nearest hotel: Убідь
# Guerrero Negro - nearest hotel: Plaza sal paraiso
# Guadalupe Y Calvo - nearest hotel: No hotel found
# Ponta Do Sol - nearest hotel: Estalagem Ponta do Sol
# Mindelo - nearest hotel: Solar Windelo
# Mackenzie - nearest hotel: No hotel found
# Taltal - nearest hotel: Hostería Taltal
# Udachnyy - nearest hotel: Вилюй
# Vostok - nearest hotel: No hotel found
# Barra Patuca - nearest hotel: No hotel found
# Plauen - nearest hotel: Hotel Alexandra
# Elizabeth City - nearest hotel: Quality Inn
# Kavaratti - nearest hotel: No hotel found
# Bhopal - nearest hotel: Hotel Panchwati
# Jackson - nearest hotel: Brookside
# Rock Sound - nearest hotel: Rock Sound Club
# Anadyr - nearest hotel: Гостевой дом
# Palampur - nearest hotel: Hotel Surbhi
# Ouadda - nearest hotel: No hotel found
# Uvira - nearest hotel: Batiment Kasangala
# Trairi - nearest hotel: No hotel found
# Barmer - nearest hotel: No hotel found
# Candolim - nearest hotel: bluesea Beach Resort
# Ulaanbaatar - nearest hotel: Этүгэн
# Christchurch - nearest hotel: Ibis Hotel Christchurch
# Deputatskiy - nearest hotel: No hotel found
# Ixtapa - nearest hotel: No hotel found
# East Foothills - nearest hotel: No hotel found
# Portobelo - nearest hotel: Luna Llena Hostal
# Xining - nearest hotel: Qinghai hotel
# Sovetskiy - nearest hotel: Кировская
# Dicabisagan - nearest hotel: No hotel found
# Pemba - nearest hotel: Hotel Rafael
# Eureka - nearest hotel: Eureka Inn, Trademark Collection by Wyndham
# Muros - nearest hotel: Pensión Ría de Muros
# Shache - nearest hotel: 莎車新盛賓舘
# Matagami - nearest hotel: Hotel Matagami
# Zhoucheng - nearest hotel: 水浒度假酒店
# Bay-Khaak - nearest hotel: No hotel found
# Luanda - nearest hotel: Hotel Forum
# Zhongshu - nearest hotel: 新天龙酒店
# Pokrovsk - nearest hotel: Дружба
# Oksfjord - nearest hotel: No hotel found
# Show Low - nearest hotel: Holiday Inn Express Showlow
# Waingapu - nearest hotel: HOTEL SANDLEWOOD
# Salisbury - nearest hotel: The Cathedral Hotel
# Kattivakkam - nearest hotel: No hotel found
# Vernon - nearest hotel: Okanagan Royal Park Inn
# Mareeba - nearest hotel: The Gateway Hotel
# Yaan - nearest hotel: No hotel found
# Tabou - nearest hotel: hôtel le rochet
# Sept-Iles - nearest hotel: Château Arnaud
# Topola - nearest hotel: No hotel found
# Polovinnoye - nearest hotel: No hotel found
# La Paz - nearest hotel: Alojamiento Tokio
# Bumbuna - nearest hotel: No hotel found
# Tigil - nearest hotel: No hotel found
# Abalak - nearest hotel: No hotel found
# Bukene - nearest hotel: No hotel found
# Belyy Yar - nearest hotel: No hotel found
# Mount Gambier - nearest hotel: The Old Mount Gambier Gaol
# Erdenet - nearest hotel: сэлэнгэ зочид буудал
# Valparaiso - nearest hotel: Ibis Hotel
# Ambon - nearest hotel: Hotel Hero
# Bandarbeyla - nearest hotel: No hotel found
# Le Mars - nearest hotel: Baymont by Wyndham LeMars
# Nador - nearest hotel: Hotel Lixus
# Malakal - nearest hotel: No hotel found
# Puerto Escondido - nearest hotel: Hotel Barlovento
# Nabire - nearest hotel: Hotel Anggrek
# Adamas - nearest hotel: Ξενοδοχείο Αγνάντι
# Cukai - nearest hotel: Hotel Shafura 2
# Lerwick - nearest hotel: Grand Hotel
# Jiutai - nearest hotel: No hotel found
# Pedernales - nearest hotel: Hostal Doña Chava
# Tadine - nearest hotel: No hotel found
# Sarramea - nearest hotel: Evasion
# Umba - nearest hotel: Гостиница
# Beian - nearest hotel: No hotel found
# Padang - nearest hotel: losmen Surya
# Chapais - nearest hotel: No hotel found
# Mecca - nearest hotel: Rehab Al Marwa Hotel 1
# Burhanpur - nearest hotel: Ambika Hotel
# Tha Chang - nearest hotel: K2 hotel wrong location. Hotel is 12km south on the main road
# Gomel - nearest hotel: Гомель
# Omemee - nearest hotel: No hotel found
# Palmer - nearest hotel: No hotel found
# Marsa Matruh - nearest hotel: صقور
# Lensk - nearest hotel: No hotel found
# Lavrentiya - nearest hotel: Фортуна
# Broome - nearest hotel: No hotel found
# Ville-Marie - nearest hotel: Hôtel Motel Caroline
# Semey - nearest hotel: Гостинница Милениум
# Komsomolskiy - nearest hotel: Hotel "Ikat House"
# Aykhal - nearest hotel: No hotel found
# Sigli - nearest hotel: No hotel found
# Soltepec - nearest hotel: No hotel found
# Tenosique - nearest hotel: Hotel Central
# Nome - nearest hotel: No hotel found
# Boyuibe - nearest hotel: No hotel found
# Penticton - nearest hotel: Fairfield by Marriott Inn & Suites Penticton
# Santa Fe - nearest hotel: Intersur Hotel
# Camacupa - nearest hotel: No hotel found
# Manakara - nearest hotel: Hotel H1
# Pringsewu - nearest hotel: No hotel found
# Batagay-Alyta - nearest hotel: No hotel found
# Sorsk - nearest hotel: No hotel found
# Khash - nearest hotel: No hotel found
# El Alto - nearest hotel: No hotel found
# San Diego De Los Banos - nearest hotel: Hotel Mirador
# Asfi - nearest hotel: Golden Tulip Farah Safi
# Tshikapa - nearest hotel: Hôtel TSHAMUNTU
# Mineros - nearest hotel: No hotel found
# Hibbing - nearest hotel: Hibbing Park Hotel
# Sawakin - nearest hotel: Hotel Halfa
# Hanyang - nearest hotel: No hotel found
# Makubetsu - nearest hotel: No hotel found
# Mandurah - nearest hotel: Forte Mandurah Quay Resort
#             City Country  Max Temp Current Description      Lat       Lng  \
# 0        Talnakh      RU     -1.71     overcast clouds  69.4865   88.3972
# 1         Burnie      AU     55.98           clear sky -41.0667  145.9167
# 2         Atuona      PF     77.67    scattered clouds  -9.8000 -139.0333
# 3     Butaritari      KI     81.05       broken clouds   3.0707  172.7902
# 4    East London      ZA     72.54    scattered clouds -33.0153   27.9116
# ..           ...     ...       ...                 ...      ...       ...
# 672      Hibbing      US      4.42    scattered clouds  47.4272  -92.9377
# 673      Sawakin      SD     85.03          few clouds  19.1059   37.3321
# 674      Hanyang      CN     42.10       broken clouds  32.1371  105.5126
# 675    Makubetsu      JP     19.11       broken clouds  45.3714  141.8211
# 676     Mandurah      AU     68.99           clear sky -32.5500  115.7000
#
#                          Hotel Name
# 0                            Талнах
# 1    Burnie Central TownHouse Hotel
# 2                      Pearl Resort
# 3                    No hotel found
# 4                    No hotel found
# ..                              ...
# 672              Hibbing Park Hotel
# 673                     Hotel Halfa
# 674                  No hotel found
# 675                  No hotel found
# 676      Forte Mandurah Quay Resort
#
# [672 rows x 7 columns]

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
hotel_df = hotel_df.dropna()

# Display sample data
hotel_df.head()
# Out:
#           City Country  Max Temp Current Description      Lat       Lng  \
# 0      Talnakh      RU     -1.71     overcast clouds  69.4865   88.3972
# 1       Burnie      AU     55.98           clear sky -41.0667  145.9167
# 2       Atuona      PF     77.67    scattered clouds  -9.8000 -139.0333
# 3   Butaritari      KI     81.05       broken clouds   3.0707  172.7902
# 4  East London      ZA     72.54    scattered clouds -33.0153   27.9116
#
#                        Hotel Name
# 0                          Талнах
# 1  Burnie Central TownHouse Hotel
# 2                    Pearl Resort
# 3                  No hotel found
# 4                  No hotel found

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"

# Export the City_Data into a csv
hotel_df.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City"
)

# Display the map plot
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp)
